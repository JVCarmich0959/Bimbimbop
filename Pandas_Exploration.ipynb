# %% [markdown]
# <a href="https://colab.research.google.com/github/JVCarmich0959/Bimbimbop/blob/main/Pandas_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Library
#
# ## What is the Pandas Library?
#
#
# Pandas is a popular open-source data analysis library for the Python programming language. It provides a variety of data manipulation and analysis tools, making it easier to work with and analyze data in Python.
#
# Pandas is particularly useful for working with tabular data, such as spreadsheets or SQL tables, as it offers powerful data structures like DataFrames and Series. These data structures allow users to easily manipulate, clean, and analyze data using built-in functions and methods.
#
# ## Why use Pandas?
#
# 1. Easy Data Handling: Pandas makes it easy to handle and manipulate data, especially for structured or tabular data.
#
# 2. Efficient Data Analysis: Pandas provides powerful tools for data analysis, such as aggregation, filtering, and transformation, making it possible to analyze large datasets quickly and efficiently.
#
# 3. Flexible Data Preparation: Pandas offers a wide range of functions and methods for cleaning and transforming data, such as removing missing values, changing data types, and merging datasets.
#
# 4. Built-in Visualization: Pandas provides built-in visualization tools that make it easy to create charts and graphs to help visualize data.
#
# 5. Integration with Other Tools: Pandas integrates seamlessly with other Python libraries, such as NumPy and Scikit-Learn, making it a valuable tool for data analysis and machine learning projects.

# %% [markdown]
# # Installation
#
# To use any library in Python, it first needs to be installed in your system. Once Pandas is installed, you can import it into your script using the 'import pandas statement. The 'pd' alias is used to make it easier to refer to the Pandas library thoughout the script or notebook.
#
# So, any time you need to use a function or method from Pandas, you can simply write the 'pd.function_name()', instead of 'pandas.function_name()', which can be time-saving and more convenient.

# %%
# importing Pandas
# If you have not already installed Pandas, you can do so by running the following command in your terminal:
# !pip3 install pandas
import pandas as pd

# %%
# some other libraries we use in this notebook
import numpy as np # numpy is a library for working with arrays and matrices
import matplotlib.pyplot as plt # matplotlib is a library for plotting data and creating visulaizations which can help us understand our data better
from matplotlib.patches import Circle, RegularPolygon # matplotlib.patches is a module which contains a number of different shapes that we can use to create cool looking visualizations
from matplotlib.path import Path # Path is a class which is used to create a path from a list of vertices and codes
from matplotlib.projections.polar import PolarAxes # PolarAxes is a class which is used to create a polar axes
from matplotlib.projections import register_projection # register_projection is a function which is used to register a projection with matplotlib
from matplotlib.spines import Spine # Spines are the lines connecting the axis tick marks and noting the boundaries of the data area
from matplotlib.transforms import Affine2D # Affine2D is a class which is used to represent an affine transformation in 2D
import seaborn as sns # seaborn is a library for creating statistical graphics in Python
# use thirtyfivethirtyeight style for matplotlib
plt.style.use('fivethirtyeight')
# import the seaborn style 
sns.set_style('darkgrid')

# %% [markdown]
# # Loading data into Pandas
#
# The code below does two things:
#
# 1. getting information from a CSV file stored GitHub
#
# 2. Loading information into a type of table Python uses called a "dataframe".
#
# ##What's a dataframe
#
# A dataframe is a way of organizing data in rows and columns, much like an Excel spreadsheet. Once the data is loaded into a dataframe, it can be analyzed, sorted, filtered, and visualized using Python code.

# %%
url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv" # In this line we are creating a variable called url and assigning it  to a string 
                                                                                    # which is the url of the csv file we want to read in from git (Pokemon Data)

df = pd.read_csv(url)   # In this line we are creating a variable called df and assigning it to the pandas function read_csv() which calls the variable url to read in the csv file from git.

# %% [markdown]
# # Data Exploration
#
# Once you have loaded the data into a DataFrame, you can use various Pandas functions to explore the data. For example. we can use df.head() to view the first few rows of the DataFrame, 'df.info()' to view the data types of the columns, 'df.describe()' to view the summary statistics of the DataFrame, and 'df.shape' to view the number of rows and columns in the DataFrame.

# %%
# Display the first 5 rows of the DataFrame
# It's important to look at your data to make sure it was read in correctly

df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# You can also use df.tail() to display the last 5 rows of the DataFrame

df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
# Display information about the DataFrame such as column names and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# # Understanding statistical information
#
# Understanding statistics is important this helps to provide a summary of data and its distribution. The 'describe()' function in pandas gives us statistical information such as count, mean, standard deviation, minimum, maximum, and quartile ranges of the numerical columns in the dataframe.
#
# By examining the statistics, we can identify potential issues in the data such as missing values outliers, and unusual distributions. We can also get a sense of the range and central tendency of the data, which can help us choose appropriate data visualization and analysis techniques.
#
# statistical information can be used to compare different subsets of the data and to evaluate the results of any data manipulation or modeling we perform. It can also help us understand the impact of any changes we make to the data or the analysis.

# %%
# Display statistical information about the DataFrame such as mean, standard deviation, etc.
print(df.describe())
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# # Understanding Shape
#
# 1. **Understanding the size of the data**: The number of rows and columns in the dataframe can give us an idea of the amount of data we are working with, which is important for planning data analysis and visualization.
#
# 2. **Identifying data quality issues**: If the number of rows or columns is significantly different from what we expected, it could be an indication of missing or incorrectly entered data.
#
# 3. **Choosing appropriate data analysis techniques**: The number of columns and their data types can determine the types of analysis techniques we can use on the data. For example, if a dataframe has a lot of numerial columns, we might want to use techniques like regression analysis or clustering, while if it has a lot of text or categorical data, we might want to use techniques like natural language processing or decision trees.
#
# 4. **Data preprocessing**: Understanding the shape of the dataframe can help us preprocess the data before we start any data analysis or modeling. For example we might need to remove columns with missing data or normalize numerical data before we can use it in our analysis.

# %%
# Display the number of rows and columns in the DataFrame
print(df.shape)
# Out:
# (800, 12)

# %% [markdown]
# # Determining the strongest and weakest Pokemon by looking at the "total" column
#
# One of the cool things about a dataframe is its iterability. Being able to stretch, pull and reconstruct the information you are presented with to gain new insights.
#
# Below I'm using the ".sort_values" function can take several parameters, but the most commonly used ones are:
#
# * 'by': the column name(s) to sort by.
# * 'ascending': a Boolean value that indicates whether to sort in ascending(True) or descending (False) order.
# * 'inplace': a Boolean value that indicates whether to modify the original dataframe(True) or return a new sorted dataframe(False,default).

# %%
# Determine the Totals for HP, Attack, Defense, Special Attack, Special Defense, and Speed
# for each Pokemon
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']

#Sort the DataFrame by the Total column in ascending order
df.sort_values('Total', ascending=False, inplace=True)

# Display the first 5 rows of the DataFrame
df.head()
# Out:
#        #                   Name     Type    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 426      180      100    115           3       True    780
# 164      194      120    140           1       True    780
# 163      154      100    130           1       True    780
# 422      180      160     90           3       True    770
# 424      150       90     90           3       True    770

# %% [markdown]
# # Filtering the data
#
# We can use Pandas to filter the data based on specific criteria. For example, we can use 'df[df['Type 1'] == 'Fire']' to filter the data to only include rows where the Pokemon is of type 'Fire'.

# %%
# Select all rows where the Type 1 column is "Fire"
fire_pokemon = df[df['Type 1'] == 'Fire'] # Here we are creating a variable called 'fire_pokemon' and reassigning it to the DataFrame df 
                                        # and using the .loc[] method to select all rows where the Type 1 column is "Fire"
# Sorting the DataFrame by the Total column in descending order
fire_pokemon = fire_pokemon.sort_values("Total", ascending=False)

# Below we are creating a bar plot of the Fire Pokemon from most powerful to least powerful using the .plot() method from matplotlib
# adjust figure size: plt.figure(figsize=(width, height))
plt.figure(figsize=(15, 15))

sns.barplot(x='Total',
            y='Name', 
            data=fire_pokemon,
            palette='autumn',
            orient='h'),
# Out:
# (<AxesSubplot:xlabel='Total', ylabel='Name'>,)

# %% [markdown]
# # Grouping the data
#
# We can group the data based on one or more columns using the 'df.groupby()' function.
# The .groupby() function in pandas is used to group rows of a DataFrame by one or more columns. It creates a group object that allows you to perform calculations and aggregations on the grouped data.
# When you call .groupby() on a DataFrame and specify one or more columns to group by, pandas splits the DataFrame into groups based on the unique values in those columns. You can then apply various aggregation functions like mean, sum, count, etc. to the grouped data.
#
# For example, we can use 'df.groupby(['Type 1])['Attack'].mean()' to group the data by the 'Type 1' column and calculate the mean of the 'Attack' column for each group.

# %%
type_stats = df.groupby("Type 1")[["Attack", "Defense"]].mean()
type_stats = type_stats.sort_values("Attack", ascending=False)
type_stats.plot(kind="bar", figsize=(15, 10), rot=0,fontsize=15, width=0.8)
plt.xlabel("Type", fontsize=15)
plt.ylabel("Average Stats", fontsize=15)
plt.title("Average Attack and Defense by Type", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Average Attack and Defense by Type')

# %% [markdown]
# # Manipulating the data:
#
# We can manipulate the dataset by adding, renaming, or removing columns.
#
# **.rename()** : the .rename() function in pandas is used to change the names of columns or indexes in a DataFrame. It takes one or more parameters to specify the new names for the columns or indexes.

# %%
# Rename the column Type 1 to Type
df = df.rename(columns={"Type 1": "Type"})

# sort the data by the Total column in descending order
df = df.sort_values("Total", ascending=False)

# Display the first 5 rows of the DataFrame
df.head()
# Out:
#        #                   Name     Type    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 426      180      100    115           3       True    780
# 163      154      100    130           1       True    780
# 164      194      120    140           1       True    780
# 422      180      160     90           3       True    770
# 424      150       90     90           3       True    770

# %% [markdown]
# # Slicing or Indexing
#
# Slicing and indexing are common operations used in pandas to extract specific subsets of data from a DataFrame.
#
# Pandas provides two primary methods for indexing and slicing: .loc and .iloc.
#
# The .loc method is used to index or slice rows and columns of a DataFrame using labels.The basic syntax of .loc is:
#
# ---
#
# df.loc[row_label, column_label]
#
#
# ---
#
# Here, row_label and colum_label are the label-based indices of the rows and columns that you want to select. You can also use the ':' character to select all rows or colums in a range.

# %%
df.loc[1:1]
# Out:
#    #     Name   Type  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 1  2  Ivysaur  Grass  Poison  60      62       63       80       80     60
#
#    Generation  Legendary  Total
# 1           1      False    405

# %%
df.loc[1:1, 'Type']
# Out:
# 1    Grass
# Name: Type, dtype: object

# %% [markdown]
# On the otherhand, the .iloc method is used to index or slice rows and colums of a DataFrame using integer positions.

# %%
df.shape

df.iloc[0:5, 0:4]
# Out:
#        #                   Name     Type    Type 2
# 426  384  RayquazaMega Rayquaza   Dragon    Flying
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting
# 422  382    KyogrePrimal Kyogre    Water       NaN
# 424  383  GroudonPrimal Groudon   Ground      Fire

# %%
# only select pokemon from generation 1
gen1 = df[df["Generation"] == 1]

gen1.head()
# Out:
#        #                       Name     Type    Type 2   HP  Attack  Defense  \
# 164  150        MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150        MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 162  150                     Mewtwo  Psychic       NaN  106     110       90
# 141  130      GyaradosMega Gyarados    Water      Dark   95     155      109
# 7      6  CharizardMega Charizard X     Fire    Dragon   78     130      111
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 164      194      120    140           1       True    780
# 163      154      100    130           1       True    780
# 162      154       90    130           1       True    680
# 141       70      130     81           1      False    640
# 7        130       85    100           1      False    634

# %%
# only select pokemon from generation 2
gen2 = df[df["Generation"] == 2]

gen2.head()
# Out:
#        #                     Name      Type  Type 2   HP  Attack  Defense  \
# 268  248  TyranitarMega Tyranitar      Rock    Dark  100     164      150
# 270  250                    Ho-oh      Fire  Flying  106     130       90
# 269  249                    Lugia   Psychic  Flying  106      90      130
# 224  208      SteelixMega Steelix     Steel  Ground   75     125      230
# 196  181    AmpharosMega Ampharos  Electric  Dragon   90      95      105
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 268       95      120     71           2      False    700
# 270      110      154     90           2       True    680
# 269       90      154    110           2       True    680
# 224       55       95     30           2      False    610
# 196      165      110     45           2      False    610

# %%
# only select legendary pokemon
legendary = df[df["Legendary"] == True]

legendary.head()
# Out:
#        #                   Name     Type    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 426      180      100    115           3       True    780
# 164      194      120    140           1       True    780
# 163      154      100    130           1       True    780
# 422      180      160     90           3       True    770
# 424      150       90     90           3       True    770

# %% [markdown]
# # Data Visualization with Pandas
#
# We can visualize the dataset using various charts and graphs such as bar charts and scatter plots. The fun part is that we can use Pandas to create visualizations. For example, we can use 'df.plot()' to create a line chart of the data. We can also use 'df.plot(kind='scatter', x='Attack', y='Defense')' to create a scatter plot of the data. We can also use 'df.plot(kind='hist')' to create a histogram of the data. Looking at data from different angles can help us gain new insights into the data and help us make better decisions.
#
# For example there are major outliers in our Pokemon data. The Dragon type and Psychic type both have skewed total means. If we were to include the legendary pokemon in our data evaluation the insights we would gain would be less than accurate. Let's look at this:

# %%
# creating a box plot for the Mean Total HP for each Type
# adjust the figure size
plt.figure(figsize=(20, 20), dpi=80, facecolor='w', edgecolor='k')
sns.boxplot(x="Type", y="Total", data=df)
plt.title("Mean Total HP for each Type", fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Mean Total HP for each Type')

# %%
# load in the original dataset
df2 = pd.read_csv(url)

#omit legendary pokemon
df2 = df2[df2["Legendary"] == False]

# create a new column called "Total" which is the sum of all the stats
df2["Total"] = df2["HP"] + df2["Attack"] + df2["Defense"] + df2["Sp. Atk"] + df2["Sp. Def"] + df2["Speed"]

# sort the data by the Total column in descending order
df2 = df2.sort_values("Total", ascending=False)

df2.head()
# Out:
#        #                     Name  Type 1   Type 2   HP  Attack  Defense  \
# 413  376  MetagrossMega Metagross   Steel  Psychic   80     145      150
# 494  445    GarchompMega Garchomp  Dragon   Ground  108     170      115
# 409  373  SalamenceMega Salamence  Dragon   Flying   95     145      130
# 268  248  TyranitarMega Tyranitar    Rock     Dark  100     164      150
# 313  289                  Slaking  Normal      NaN  150     160      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 413      105      110    110           3      False    700
# 494      120       95     92           4      False    700
# 409      120       90    120           3      False    700
# 268       95      120     71           2      False    700
# 313       95       65    100           3      False    670

# %%
#Now create a boxplot for the mean total HP for our new dataset without legendary pokemon
# adjust the figure size
plt.figure(figsize=(20, 20), dpi=80, facecolor='w', edgecolor='k')
sns.boxplot(x="Type 1", y="Total", data=df2)
plt.title("Mean Total HP for each Type(without Legendary)", fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Mean Total HP for each Type(without Legendary)')

# %%
# Compare each generation's mean Total points
sns.boxplot(x="Generation", y="Total", data=df)
plt.title("Mean Total HP for each Generation (With Legendary Pokemon)", fontsize=20, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Mean Total HP for each Generation (With Legendary Pokemon)')

# %% [markdown]
# Generation 3 Pokemon have the highest average total stats.  Let's take a look at the data:

# %%
gen3 = df[df["Generation"] == 3]
gen3.head()

# AH yes...Rayquaza...the most powerful pokemon of all time...that could make things less accurate
# Out:
#        #                   Name    Type   Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza  Dragon   Flying  105     180      100
# 422  382    KyogrePrimal Kyogre   Water      NaN  100     150       90
# 424  383  GroudonPrimal Groudon  Ground     Fire  100     180      160
# 418  380      LatiasMega Latias  Dragon  Psychic   80     100      120
# 420  381      LatiosMega Latios  Dragon  Psychic   80     130      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 426      180      100    115           3       True    780
# 422      180      160     90           3       True    770
# 424      150       90     90           3       True    770
# 418      140      150    110           3       True    700
# 420      160      120    110           3       True    700

# %%
# Let's look at the generation's minus the legendary pokemon
sns.boxplot(x="Generation", y="Total", data=df2)
plt.title("Mean Total HP for each Generation (Without Legendary Pokemon)", fontsize=20, fontweight="bold")

# you can see that the y axis parameters shrunk significantly and the representation of the data is much more accurate
# Out:
# Text(0.5, 1.0, 'Mean Total HP for each Generation (Without Legendary Pokemon)')

# %% [markdown]
# Pretty awesome right? We can see how much the mean total of each generation is affected by those pesky legendary pokemon. We can also see that the legendary pokemon are not the only outliers in our data. The Dragon type and Psychic type both have skewed total means.

# %%
# Determine how many of each Type are in each generation
# First we need to create a pivot table

type_gen = pd.pivot_table(df, index="Type", columns="Generation", values="Name", aggfunc="count")
type_gen = type_gen.fillna(0) # I love the pandas fillna() method. It's very useful for filling in missing values and data cleaning.
type_gen = type_gen.astype(int)

# display the pivot table
type_gen
# Out:
# Generation   1   2   3   4   5   6
# Type
# Bug         14  12  12  10  18   3
# Dark         0   6   6   3  13   3
# Dragon       3   0  12   4   9   4
# Electric     9   7   5  12   8   3
# Fairy        2   5   0   1   0   9
# Fighting     7   2   5   3   7   3
# Fire        14   8   8   5   9   8
# Flying       0   0   0   0   2   2
# Ghost        4   1   5   7   5  10
# Grass       13   9  13  15  15   5
# Ground       8   3   7   4  10   0
# Ice          2   4   7   3   6   2
# Normal      24  15  18  18  19   4
# Poison      14   1   3   6   2   2
# Psychic     11   7  12   8  14   5
# Rock        10   5   8   6   6   9
# Steel        0   3  12   3   4   5
# Water       31  18  27  13  18   5

# %%
# This function sets up the radar charts 

def radar_factory(num_vars, frame='circle'):
    """
    Create a radar chart with `num_vars` axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle', 'polygon'}
        Shape of frame surrounding axes.

    """
    # calculate evenly-spaced axis angles
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    class RadarTransform(PolarAxes.PolarTransform): # this class is used to transform the data into a radar chart

        def transform_path_non_affine(self, path):
            # Paths with non-unit interpolation steps correspond to gridlines,
            # in which case we force interpolation (to defeat PolarTransform's
            # autoconversion to circular arcs).
            if path._interpolation_steps > 1:
                path = path.interpolated(num_vars)
            return Path(self.transform(path.vertices), path.codes)

    class RadarAxes(PolarAxes): # this class is used to create the radar chart

        name = 'radar' # name of the class
        PolarTransform = RadarTransform # this class is used to transform the data into a radar chart

        def __init__(self, *args, **kwargs): # this function is used to initialize the class
            super().__init__(*args, **kwargs) # this function is used to initialize the class
            # rotate plot such that the first axis is at the top
            self.set_theta_zero_location('N') # this function is used to set the location of the first axis

        def fill(self, *args, closed=True, **kwargs): # this function is used to fill the radar chart
            """Override fill so that line is closed by default""" # this function is used to fill the radar chart
            return super().fill(closed=closed, *args, **kwargs) # this function is used to fill the radar chart

        def plot(self, *args, **kwargs): # this function is used to plot the radar chart
            """Override plot so that line is closed by default"""
            lines = super().plot(*args, **kwargs)
            for line in lines: # this for loop is iterates through the lines in the radar chart
                self._close_line(line) # this function is used to close the lines in the radar chart

        def _close_line(self, line):
            x, y = line.get_data()  # the .get_data() function is used to get the data from the radar chart
            # FIXME: markers at x[0], y[0] get doubled-up
            if x[0] != x[-1]:
                x = np.append(x, x[0]) # this function is used to append the x values to a list
                y = np.append(y, y[0])  # this function is used to append the y values to a list
                line.set_data(x, y) # this function is used to set the data for the radar chart

        def set_varlabels(self, labels): # this function is used to set the labels for the radar chart
            self.set_thetagrids(np.degrees(theta), labels) # this function is used to set the labels for the radar chart

        def _gen_axes_patch(self):
            # The Axes patch must be centered at (0.5, 0.5) and of radius 0.5
            # in axes coordinates.
            if frame == 'circle': # if the frame is a circle
                return Circle((0.5, 0.5), 0.5) # return a circle
            elif frame == 'polygon': # if the frame is a polygon 
                return RegularPolygon((0.5, 0.5), num_vars, # return a polygon
                                      radius=.5, edgecolor="k") 
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame) # if the frame is not a circle or a polygon, raise an error

        def _gen_axes_spines(self): # this function is used to generate the axes spines
            if frame == 'circle': # if the frame is a circle
                return super()._gen_axes_spines() # return the super class
            elif frame == 'polygon': # if the frame is a polygon
                # spine_type must be 'left'/'right'/'top'/'bottom'/'circle'.
                spine = Spine(axes=self, # return a spine
                              spine_type='circle', # return a spine
                              path=Path.unit_regular_polygon(num_vars)) 
                
                


# Defining the data for the Holy Trinity Radar Charts

pokemon_data = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv') # reading in a fresh copy of the pokemon data
pokemon_data = pokemon_data.set_index('#') # setting the index to the pokemon number
pikachu = pokemon_data.loc[25] # getting the data for pikachu
charmander = pokemon_data.loc[4] # getting the data for charmander
squirtle = pokemon_data.loc[7] # getting the data for squirtle

# Define function to create spider chart
def radar_chart(ax, data_list, colors):
    # Get list of feature names and values for each data point
    feature_names = list(data_list[0].keys())[1:] # getting the feature names
    num_features = len(feature_names) # number of features
    for i, data in enumerate(data_list): # this for loop is used to iterate through the data
        values = [data[feature] for feature in feature_names]  # getting the values for each feature
        # Calculate angle for each feature
        angles = [n / float(num_features) * 2 * np.pi for n in range(num_features)] # calculating the angle for each feature 
        angles += angles[:1] # adding the first angle to the end of the list
        values += values[:1] # adding the first value to the end of the list
        # Normalize values
        max_value = max(values)
        values = [float(v)/max_value for v in values]
        # Plot radar chart
        ax.plot(angles, values, color=colors[i], linewidth=2, label=data['Name'])
        ax.fill(angles, values, color=colors[i], alpha=0.25)
    # Set axis limits and ticks
    ax.set_ylim([0, 1])
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(feature_names)
    ax.yaxis.grid(True)
    # Add legend
    ax.legend(loc='upper right', bbox_to_anchor=(1.4, 1.2))


# Create figure and axes
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(16, 6), subplot_kw=dict(polar=True))

# Create list of data for each Pokemon by selecting rows from dataframe



pikachu = {'Name': 'Pikachu', 'HP': 35, 'Attack': 55, 'Defense': 40, 'Sp. Atk': 50, 'Sp. Def': 50, 'Speed': 90}
charmander= {'Name': 'Charmander', 'HP': 39, 'Attack': 52, 'Defense': 43, 'Sp. Atk': 60, 'Sp. Def': 50, 'Speed': 65}
squirtle = {'Name': 'Squirtle', 'HP': 44, 'Attack': 48, 'Defense': 65, 'Sp. Atk': 50, 'Sp. Def': 64, 'Speed': 43}
data = [pikachu, charmander, squirtle]



# Create radar chart for each Pokemon
colors = ['yellow', 'orange', 'teal']
for i, ax in enumerate(axs.flat):
    radar_chart(ax, data[i:i+1], colors[i:i+1])

    # add titles to each subplot
    ax.set_title(data[i]['Name'], position=(0.5, 1.1), ha='center')


plt.show()

# %% [markdown]
# # This area is for my son who is 5 years old:
#
# Kahlil is interested in the "strongest guys" in the Pokemon world. He wants to know which Pokemon have the highest stats. Visualizing data is very helpful for preschoolers to understand multidimensional data.

# %%
# Grabbing the top 10 pokemon by total stats

top_10_legendary= legendary.sort_values('Total', ascending=False).head(10) # sorting the legendary pokemon by total stats and grabbing the top 10

top_10_legendary # displaying the top 10 legendary pokemon
# Out:
#        #                   Name     Type    Type 2   HP  Attack  Defense  \
# 426  384  RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN  106     150       70
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 422  382    KyogrePrimal Kyogre    Water       NaN  100     150       90
# 424  383  GroudonPrimal Groudon   Ground      Fire  100     180      160
# 552  493                 Arceus   Normal       NaN  120     120      120
# 711  646     KyuremBlack Kyurem   Dragon       Ice  125     170      100
# 712  646     KyuremWhite Kyurem   Dragon       Ice  125     120       90
# 420  381      LatiosMega Latios   Dragon   Psychic   80     130      100
# 796  719    DiancieMega Diancie     Rock     Fairy   50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 426      180      100    115           3       True    780
# ...

# %%
# bar chart of the top 10 legendary pokemon by Total Stats

sns. set_style('whitegrid') # setting the style of the bar chart
plt.figure(figsize=(12,6)) # setting the size of the bar chart
sns.barplot(x='Total', y='Name', data=top_10_legendary, palette='rocket') # creating the bar chart
plt.title('Top 10 "Strongest Guys"') # adding a title to the bar chart
plt.show() # displaying the bar chart
